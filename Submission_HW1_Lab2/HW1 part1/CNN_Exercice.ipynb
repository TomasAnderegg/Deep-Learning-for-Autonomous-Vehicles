# %% [markdown]
# ## Convolutional Networks
#
# We'll check out how to build a **convolutional network** to classify CIFAR10 images. By using weight sharing - multiple units with the same weights - convolutional layers are able to learn repeated patterns in your data. For example, a unit could learn the pattern for an eye, or a face, or lower level features like edges.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torch.utils.data as utils
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import torchvision.utils as vutils
from torchvision.datasets import CIFAR10

# %matplotlib inline

# %%
label_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]


def plot_images(images, cls_true, cls_pred=None):
    """
    Adapted from https://github.com/Hvass-Labs/TensorFlow-Tutorials/
    """
    fig, axes = plt.subplots(3, 3)

    for i, ax in enumerate(axes.flat):
        # plot img
        ax.imshow(images[i, :, :, :], interpolation='spline16')

        # show true & predicted classes
        cls_true_name = label_names[cls_true[i]]
        if cls_pred is None:
            xlabel = "{0} ({1})".format(cls_true_name, cls_true[i])
        else:
            cls_pred_name = label_names[cls_pred[i]]
            xlabel = "True: {0}\nPred: {1}".format(
                cls_true_name, cls_pred_name
            )
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %%
def get_train_valid_loader(data_dir='data',
                           batch_size=64,
                           augment=False,
                           random_seed=1,
                           valid_size=0.02,
                           shuffle=True,
                           show_sample=True,
                           num_workers=4,
                           pin_memory=False):
    """
    Utility function for loading and returning train and valid
    multi-process iterators over the CIFAR-10 dataset. A sample
    9x9 grid of the images can be optionally displayed.
    If using CUDA, num_workers should be set to 1 and pin_memory to True.
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms for validation (no augmentation)
    valid_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # Define the transform for training (and data augmentation)

    train_transform = transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.RandomCrop(32, padding=4),
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
            transforms.ToTensor(),
            normalize
    ])

    # load the dataset
    train_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    # visualize some images if requested
    if show_sample:
        sample_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=9, shuffle=shuffle,
            num_workers=num_workers, pin_memory=pin_memory,
        )
        data_iter = iter(sample_loader)
        images, labels = next(data_iter)
        # Unnormalize the images for display
        mean = [0.4914, 0.4822, 0.4465]
        std = [0.2023, 0.1994, 0.2010]
        unnorm_images = [unnormalize(img, mean, std) for img in images]
        X = torch.stack(unnorm_images).numpy().transpose([0, 2, 3, 1])
        plot_images(X, labels)

    return (train_loader, valid_loader)

def unnormalize(img, mean, std):
    img = img * torch.tensor(std).view(3, 1, 1) + torch.tensor(mean).view(3, 1, 1)
    return img

trainloader, valloader = get_train_valid_loader(augment=True)
# Out:
# /opt/jlab-env/lib/python3.12/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..0.827451].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..0.87058824].

# %% [markdown]
# # Convolutional Neural Network Architecture

# %% [markdown]
# Let's first talk about the overall architecture of a CNN and how each dimension evolves after each layer, we'll take as example the first and famous CNN LeNet5 :
# <figure align="center">
#   <img src="https://doimages.nyc3.cdn.digitaloceanspaces.com/010AI-ML/content/images/2021/10/image-17.png" alt="LeNet5 Architecture" width="600">
#   <figcaption>Image credit: <a href="https://en.wikipedia.org">Wikipedia</a></figcaption>
# </figure>

# %% [markdown]
# For that, we will have some quick questions to see if you understand what happens during training/inference:
#
# ### 1. First Layer Convolution
#
# If we consider the input of LeNet5 to be CIFAR-10, what would be the shape of the parameters of the first convolutional layer (stride = 1)?
#
# - **A.** `torch.Size([6, 1, 5, 5])`
# - **B.** `torch.Size([6, 3, 3, 3])`
# - **C.** `torch.Size([6, 1, 5, 5])`
# - **D.** `torch.Size([6, 3, 5, 5])`
#
# **Answer**: D, because out_channels is 6, in_channels= 3 (RGB for CIFAR-10) and kernel_height and width = 5x5 which give a feature map of 28x28
#
# ---
#
# ### 2. Subsampling Window
#
# What is the shape of the subsampling window (stride = 2) for the second layer (between C1 and C2), and does this shape remain invariant regardless of the subsampling method (e.g., Avg pooling or Max pooling)?
#
# - **A.** `2x2, yes it does`
# - **B.** `3x3, no it doesn't`
# - **C.** `2x2, no it doesn't`
# - **D.** `yes, it does`
#
# **Answer**: A: 2x2, yes it does
#
# By applying:
# (output image size) = (N-K)/stride + 1;
# with N: image size, K: kernel size.
# We find 2x2.
# Yes the shape remain invariant. The subsampling methods use the same window the internal mathematical operation changes. SO the window size does not depend on the subsampling method.
#
# ---
#
# ### 3. Backpropagation for Convolutional Filters
#
# Do the filters in the convolutional layers also benefit from backpropagation?
#
# **Answer**: Yes the filters benefit from backprop.
# Convolutional filters are learnable parameters so during training:
#
# - Loss is computed
#
# - Gradients are backpropagated
#
# - Filter weights are updated via gradient descent
#
# ---
#
# ### 4. Role of the Fully-Connected Layer
#
# Explain in your own words why it is necessary to have a fully-connected layer in the architecture.
#
# **Answer**: Thanks to the convolution layers, the model leanrs features but it still needs to classify the image based on these features. The fully-connexted layer flattens the feature maps, combines all the features and produces a final prediction that allows classification.
#
# ---
#
# If you had any struggle to answer one of theses questions, feel free to ask a TA about intuition or hints about the solution.

# %% [markdown]
# # Build your own Convolutional Neural Network Architecture

# %% [markdown]
# ## Different ways to improve the accuracy of your network :
# - Change the number of convolutions and layers (you can take inspiration from internet as you as you cite the architecture)
# - Change the optmizer / its hyperparameters
# - Add new types of layers
# - Do some data augmentation in the get_train_valid_loader function (flipped, cropped, uncentered images) cf. https://pytorch.org/vision/stable/transforms.html

# %%
class ConvNet(nn.Module):
    def __init__(self, n_input_channels=3, n_output=10):
        super().__init__()
        ################################################################################
        # TODO:                                                                        #
        # Define 2 or more different layers of the neural network                      #
        ################################################################################
        self.conv1 = nn.Conv2d(n_input_channels, 32, 3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(2, 2)

        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.pool2 = nn.MaxPool2d(2, 2)

        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.pool3 = nn.MaxPool2d(2, 2)  # 8x8 -> 4x4
        self.dropout = nn.Dropout(0.3)
        self.fc1 = nn.Linear(128 * 4 * 4, 256)
        self.fc2 = nn.Linear(256, n_output)
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

    def forward(self, x):
        ################################################################################
        # TODO:                                                                        #
        # Set up the forward pass that the input data will go through.                 #
        # A good activation function betweent the layers is a ReLu function.           #
        #                                                                              #
        # Note that the output of the last convolution layer should be flattened       #
        # before being inputted to the fully connected layer. We can flatten           #
        # Tensor `x` with `x.view`.                                                    #
        ################################################################################
        x = self.pool1(F.relu(self.bn1(self.conv1(x))))
        x = self.pool2(F.relu(self.bn2(self.conv2(x))))
        x = self.pool3(F.relu(self.bn3(self.conv3(x))))
        x = x.view(-1, 128 * 4 * 4)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.fc2(x)
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        return x

    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
net = ConvNet()
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001, weight_decay=1e-4)


epochs = 15
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
steps = 0
running_loss = 0
print_every = 20
for e in range(epochs):
    start = time.time()
    for images, labels in iter(trainloader):

        steps += 1
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        #                                                                              #
        ################################################################################
        optimizer.zero_grad()
        output = net(images)
        targets = labels
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        loss = criterion(output, targets)
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        # HINT: Calculate the gradient and move one step further                       #
        ################################################################################
        loss.backward()
        optimizer.step()
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        running_loss += loss.item()

        if steps % print_every == 0:
            stop = time.time()
            # Test accuracy
            accuracy = 0
            for ii, (images, labels) in enumerate(valloader):

                ################################################################################
                # TODO:                                                                        #
                # Calculate the accuracy                                                       #
                ################################################################################
                
                with torch.no_grad():
                    net.eval()
                    output = net(images)
                    _, prediction = torch.max(output, 1)
                    accuracy += torch.sum(prediction == labels).item()
                    net.train()
                ################################################################################
                #                              END OF YOUR CODE                                #
                ################################################################################

            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Loss: {:.4f}..".format(running_loss/print_every),
                  "Test accuracy: {:.4f}..".format(accuracy/(ii+1)),
                  "{:.4f} s/batch".format((stop - start)/print_every)
                 )
            running_loss = 0
            start = time.time()
    scheduler.step()
# Out:
# Epoch: 1/15.. Loss: 2.2425.. Test accuracy: 13.1875.. 0.1016 s/batch
# Epoch: 1/15.. Loss: 1.9519.. Test accuracy: 19.1250.. 0.1083 s/batch
# Epoch: 1/15.. Loss: 1.9077.. Test accuracy: 21.9375.. 0.0983 s/batch
# Epoch: 1/15.. Loss: 1.8282.. Test accuracy: 23.8125.. 0.1177 s/batch
# Epoch: 1/15.. Loss: 1.7950.. Test accuracy: 22.5000.. 0.1097 s/batch
# Epoch: 1/15.. Loss: 1.7706.. Test accuracy: 24.2500.. 0.1064 s/batch
# Epoch: 1/15.. Loss: 1.7494.. Test accuracy: 27.2500.. 0.0959 s/batch
# Epoch: 1/15.. Loss: 1.6815.. Test accuracy: 23.3750.. 0.1033 s/batch
# Epoch: 1/15.. Loss: 1.6152.. Test accuracy: 24.7500.. 0.1147 s/batch
# Epoch: 1/15.. Loss: 1.6207.. Test accuracy: 29.0625.. 0.1014 s/batch
# Epoch: 1/15.. Loss: 1.5769.. Test accuracy: 30.5625.. 0.1000 s/batch
# Epoch: 1/15.. Loss: 1.5506.. Test accuracy: 29.0000.. 0.1108 s/batch
# Epoch: 1/15.. Loss: 1.5915.. Test accuracy: 26.5625.. 0.0888 s/batch
# Epoch: 1/15.. Loss: 1.5346.. Test accuracy: 30.4375.. 0.0983 s/batch
# Epoch: 1/15.. Loss: 1.5194.. Test accuracy: 30.8125.. 0.1037 s/batch
# Epoch: 1/15.. Loss: 1.5330.. Test accuracy: 31.1875.. 0.0920 s/batch
# Epoch: 1/15.. Loss: 1.4775.. Test accuracy: 31.4375.. 0.1103 s/batch
# Epoch: 1/15.. Loss: 1.5583.. Test accuracy: 32.5000.. 0.0903 s/batch
# Epoch: 1/15.. Loss: 1.4578.. Test accuracy: 31.5625.. 0.1041 s/batch
# Epoch: 1/15.. Loss: 1.4517.. Test accuracy: 33.4375.. 0.1037 s/batch
# Epoch: 1/15.. Loss: 1.4547.. Test accuracy: 33.7500.. 0.0995 s/batch
# Epoch: 1/15.. Loss: 1.4488.. Test accuracy: 32.8125.. 0.1153 s/batch
# Epoch: 1/15.. Loss: 1.4283.. Test accuracy: 32.1875.. 0.1000 s/batch
# Epoch: 1/15.. Loss: 1.4059.. Test accuracy: 33.1875.. 0.1044 s/batch
# Epoch: 1/15.. Loss: 1.3945.. Test accuracy: 33.1250.. 0.0975 s/batch
# Epoch: 1/15.. Loss: 1.3998.. Test accuracy: 32.8750.. 0.1183 s/batch
# Epoch: 1/15.. Loss: 1.2975.. Test accuracy: 35.9375.. 0.1223 s/batch
# Epoch: 1/15.. Loss: 1.4079.. Test accuracy: 36.5625.. 0.0990 s/batch
# Epoch: 1/15.. Loss: 1.3654.. Test accuracy: 35.9375.. 0.1035 s/batch
# Epoch: 1/15.. Loss: 1.3319.. Test accuracy: 36.1875.. 0.1115 s/batch
# Epoch: 1/15.. Loss: 1.3344.. Test accuracy: 36.0625.. 0.1085 s/batch
# Epoch: 1/15.. Loss: 1.3858.. Test accuracy: 31.6875.. 0.0990 s/batch
# Epoch: 1/15.. Loss: 1.2951.. Test accuracy: 36.3125.. 0.0870 s/batch
# Epoch: 1/15.. Loss: 1.3391.. Test accuracy: 37.3125.. 0.0980 s/batch
# Epoch: 1/15.. Loss: 1.3294.. Test accuracy: 35.6875.. 0.1078 s/batch
# Epoch: 1/15.. Loss: 1.2977.. Test accuracy: 36.9375.. 0.1027 s/batch
# Epoch: 1/15.. Loss: 1.2742.. Test accuracy: 38.1250.. 0.1165 s/batch
# Epoch: 1/15.. Loss: 1.2801.. Test accuracy: 36.8125.. 0.0937 s/batch
# Epoch: 2/15.. Loss: 1.2773.. Test accuracy: 37.5625.. 0.0914 s/batch
# Epoch: 2/15.. Loss: 1.2803.. Test accuracy: 36.3750.. 0.0987 s/batch
# Epoch: 2/15.. Loss: 1.2244.. Test accuracy: 37.9375.. 0.0975 s/batch
# Epoch: 2/15.. Loss: 1.2248.. Test accuracy: 37.5625.. 0.1098 s/batch
# Epoch: 2/15.. Loss: 1.2716.. Test accuracy: 36.5000.. 0.1133 s/batch
# Epoch: 2/15.. Loss: 1.2845.. Test accuracy: 37.0000.. 0.1003 s/batch
# Epoch: 2/15.. Loss: 1.2085.. Test accuracy: 37.2500.. 0.1150 s/batch
# Epoch: 2/15.. Loss: 1.2815.. Test accuracy: 36.8125.. 0.0950 s/batch
# Epoch: 2/15.. Loss: 1.2578.. Test accuracy: 40.8125.. 0.1066 s/batch
# Epoch: 2/15.. Loss: 1.1739.. Test accuracy: 37.9375.. 0.0901 s/batch
# Epoch: 2/15.. Loss: 1.2005.. Test accuracy: 38.6250.. 0.0999 s/batch
# Epoch: 2/15.. Loss: 1.2172.. Test accuracy: 39.1250.. 0.1075 s/batch
# Epoch: 2/15.. Loss: 1.2294.. Test accuracy: 38.8125.. 0.0960 s/batch
# Epoch: 2/15.. Loss: 1.2119.. Test accuracy: 39.6875.. 0.0954 s/batch
# Epoch: 2/15.. Loss: 1.2096.. Test accuracy: 39.7500.. 0.0993 s/batch
# Epoch: 2/15.. Loss: 1.1789.. Test accuracy: 39.9375.. 0.1059 s/batch
# Epoch: 2/15.. Loss: 1.2165.. Test accuracy: 39.3750.. 0.1088 s/batch
# Epoch: 2/15.. Loss: 1.1778.. Test accuracy: 39.1250.. 0.0995 s/batch
# Epoch: 2/15.. Loss: 1.2090.. Test accuracy: 40.1875.. 0.1003 s/batch
# Epoch: 2/15.. Loss: 1.1014.. Test accuracy: 40.1875.. 0.1054 s/batch
# Epoch: 2/15.. Loss: 1.2014.. Test accuracy: 36.4375.. 0.0935 s/batch
# Epoch: 2/15.. Loss: 1.1597.. Test accuracy: 37.8750.. 0.0949 s/batch
# Epoch: 2/15.. Loss: 1.2375.. Test accuracy: 39.8125.. 0.0929 s/batch
# Epoch: 2/15.. Loss: 1.1906.. Test accuracy: 40.0000.. 0.0955 s/batch
# Epoch: 2/15.. Loss: 1.1953.. Test accuracy: 40.0625.. 0.0944 s/batch
# Epoch: 2/15.. Loss: 1.1553.. Test accuracy: 41.1250.. 0.0951 s/batch
# Epoch: 2/15.. Loss: 1.1838.. Test accuracy: 39.7500.. 0.0905 s/batch
# Epoch: 2/15.. Loss: 1.1506.. Test accuracy: 39.1250.. 0.0928 s/batch
# Epoch: 2/15.. Loss: 1.1741.. Test accuracy: 37.6250.. 0.0886 s/batch
# Epoch: 2/15.. Loss: 1.1307.. Test accuracy: 41.3750.. 0.1146 s/batch
# Epoch: 2/15.. Loss: 1.1397.. Test accuracy: 40.4375.. 0.1032 s/batch
# Epoch: 2/15.. Loss: 1.1612.. Test accuracy: 38.3750.. 0.0939 s/batch
# Epoch: 2/15.. Loss: 1.1356.. Test accuracy: 41.1875.. 0.1037 s/batch
# Epoch: 2/15.. Loss: 1.0948.. Test accuracy: 40.3750.. 0.1034 s/batch
# Epoch: 2/15.. Loss: 1.1785.. Test accuracy: 40.3750.. 0.1016 s/batch
# Epoch: 2/15.. Loss: 1.1005.. Test accuracy: 41.3750.. 0.1038 s/batch
# Epoch: 2/15.. Loss: 1.0939.. Test accuracy: 41.3750.. 0.1070 s/batch
# Epoch: 2/15.. Loss: 1.1629.. Test accuracy: 41.8750.. 0.0941 s/batch
# Epoch: 3/15.. Loss: 1.0495.. Test accuracy: 41.0000.. 0.0521 s/batch
# Epoch: 3/15.. Loss: 1.1323.. Test accuracy: 41.4375.. 0.0946 s/batch
# Epoch: 3/15.. Loss: 1.0685.. Test accuracy: 38.1875.. 0.1031 s/batch
# Epoch: 3/15.. Loss: 1.0854.. Test accuracy: 40.3125.. 0.1040 s/batch
# Epoch: 3/15.. Loss: 1.0575.. Test accuracy: 41.6250.. 0.1085 s/batch
# Epoch: 3/15.. Loss: 1.1184.. Test accuracy: 41.6250.. 0.1051 s/batch
# Epoch: 3/15.. Loss: 1.0673.. Test accuracy: 41.1875.. 0.1117 s/batch
# Epoch: 3/15.. Loss: 1.0813.. Test accuracy: 41.3750.. 0.1061 s/batch
# Epoch: 3/15.. Loss: 1.0958.. Test accuracy: 40.8125.. 0.1150 s/batch
# Epoch: 3/15.. Loss: 1.1343.. Test accuracy: 41.7500.. 0.1072 s/batch
# Epoch: 3/15.. Loss: 1.0842.. Test accuracy: 40.6875.. 0.0881 s/batch
# Epoch: 3/15.. Loss: 1.0951.. Test accuracy: 41.5000.. 0.1067 s/batch
# Epoch: 3/15.. Loss: 1.0477.. Test accuracy: 42.3125.. 0.1043 s/batch
# Epoch: 3/15.. Loss: 1.0727.. Test accuracy: 41.6250.. 0.1001 s/batch
# Epoch: 3/15.. Loss: 1.0971.. Test accuracy: 41.8125.. 0.1062 s/batch
# Epoch: 3/15.. Loss: 1.0778.. Test accuracy: 41.7500.. 0.1129 s/batch
# Epoch: 3/15.. Loss: 1.1059.. Test accuracy: 41.1250.. 0.1009 s/batch
# Epoch: 3/15.. Loss: 1.0885.. Test accuracy: 42.6250.. 0.1085 s/batch
# Epoch: 3/15.. Loss: 1.0360.. Test accuracy: 43.1250.. 0.1017 s/batch
# Epoch: 3/15.. Loss: 1.0802.. Test accuracy: 41.6875.. 0.0985 s/batch
# Epoch: 3/15.. Loss: 1.0128.. Test accuracy: 43.1875.. 0.0965 s/batch
# Epoch: 3/15.. Loss: 1.0624.. Test accuracy: 42.6250.. 0.0987 s/batch
# Epoch: 3/15.. Loss: 1.0327.. Test accuracy: 40.0000.. 0.1164 s/batch
# Epoch: 3/15.. Loss: 1.0735.. Test accuracy: 41.6875.. 0.1152 s/batch
# Epoch: 3/15.. Loss: 1.0794.. Test accuracy: 41.1875.. 0.0951 s/batch
# Epoch: 3/15.. Loss: 0.9685.. Test accuracy: 42.8750.. 0.0983 s/batch
# Epoch: 3/15.. Loss: 1.0969.. Test accuracy: 41.9375.. 0.1184 s/batch
# Epoch: 3/15.. Loss: 1.0552.. Test accuracy: 42.3125.. 0.0992 s/batch
# Epoch: 3/15.. Loss: 0.9749.. Test accuracy: 44.1250.. 0.1070 s/batch
# Epoch: 3/15.. Loss: 1.0521.. Test accuracy: 42.9375.. 0.1120 s/batch
# Epoch: 3/15.. Loss: 1.0419.. Test accuracy: 43.3125.. 0.1039 s/batch
# Epoch: 3/15.. Loss: 0.9995.. Test accuracy: 43.2500.. 0.1380 s/batch
# Epoch: 3/15.. Loss: 1.0556.. Test accuracy: 42.2500.. 0.1000 s/batch
# Epoch: 3/15.. Loss: 1.0461.. Test accuracy: 42.3125.. 0.0956 s/batch
# Epoch: 3/15.. Loss: 0.9946.. Test accuracy: 42.9375.. 0.1153 s/batch
# Epoch: 3/15.. Loss: 0.9831.. Test accuracy: 43.0000.. 0.1107 s/batch
# Epoch: 3/15.. Loss: 1.0572.. Test accuracy: 43.9375.. 0.0996 s/batch
# Epoch: 4/15.. Loss: 1.0307.. Test accuracy: 43.0625.. 0.0208 s/batch
# Epoch: 4/15.. Loss: 1.0185.. Test accuracy: 44.0625.. 0.1065 s/batch
# Epoch: 4/15.. Loss: 0.9959.. Test accuracy: 43.0000.. 0.1177 s/batch
# Epoch: 4/15.. Loss: 1.0260.. Test accuracy: 42.6250.. 0.1004 s/batch
# Epoch: 4/15.. Loss: 1.0218.. Test accuracy: 43.8750.. 0.1194 s/batch
# Epoch: 4/15.. Loss: 1.0194.. Test accuracy: 45.0000.. 0.1031 s/batch
# Epoch: 4/15.. Loss: 0.8986.. Test accuracy: 45.0000.. 0.0932 s/batch
# Epoch: 4/15.. Loss: 0.9582.. Test accuracy: 43.9375.. 0.0974 s/batch
# Epoch: 4/15.. Loss: 0.9450.. Test accuracy: 43.9375.. 0.1075 s/batch
# Epoch: 4/15.. Loss: 0.9709.. Test accuracy: 42.8750.. 0.1164 s/batch
# Epoch: 4/15.. Loss: 1.0257.. Test accuracy: 43.8125.. 0.1222 s/batch
# Epoch: 4/15.. Loss: 0.9719.. Test accuracy: 43.3750.. 0.1121 s/batch
# Epoch: 4/15.. Loss: 0.9960.. Test accuracy: 44.6250.. 0.1062 s/batch
# Epoch: 4/15.. Loss: 0.9968.. Test accuracy: 42.1250.. 0.1075 s/batch
# Epoch: 4/15.. Loss: 0.9897.. Test accuracy: 44.0625.. 0.1013 s/batch
# Epoch: 4/15.. Loss: 0.9194.. Test accuracy: 44.5000.. 0.1022 s/batch
# Epoch: 4/15.. Loss: 1.0083.. Test accuracy: 43.4375.. 0.0951 s/batch
# Epoch: 4/15.. Loss: 1.0121.. Test accuracy: 44.8125.. 0.0968 s/batch
# Epoch: 4/15.. Loss: 0.9749.. Test accuracy: 44.6875.. 0.1005 s/batch
# Epoch: 4/15.. Loss: 0.9444.. Test accuracy: 44.9375.. 0.0969 s/batch
# Epoch: 4/15.. Loss: 0.9294.. Test accuracy: 44.0625.. 0.1148 s/batch
# Epoch: 4/15.. Loss: 0.9368.. Test accuracy: 42.6250.. 0.1009 s/batch
# Epoch: 4/15.. Loss: 0.9878.. Test accuracy: 44.5625.. 0.1047 s/batch
# Epoch: 4/15.. Loss: 0.9210.. Test accuracy: 44.8125.. 0.0954 s/batch
# Epoch: 4/15.. Loss: 0.9455.. Test accuracy: 43.3750.. 0.0917 s/batch
# Epoch: 4/15.. Loss: 0.9922.. Test accuracy: 44.6875.. 0.1110 s/batch
# Epoch: 4/15.. Loss: 1.0055.. Test accuracy: 45.9375.. 0.0958 s/batch
# Epoch: 4/15.. Loss: 0.9896.. Test accuracy: 45.8750.. 0.1008 s/batch
# Epoch: 4/15.. Loss: 0.9405.. Test accuracy: 41.4375.. 0.1012 s/batch
# Epoch: 4/15.. Loss: 0.9820.. Test accuracy: 42.5625.. 0.0931 s/batch
# Epoch: 4/15.. Loss: 1.0101.. Test accuracy: 44.6250.. 0.1140 s/batch
# Epoch: 4/15.. Loss: 0.9243.. Test accuracy: 44.0625.. 0.1081 s/batch
# Epoch: 4/15.. Loss: 1.0069.. Test accuracy: 44.7500.. 0.1177 s/batch
# Epoch: 4/15.. Loss: 0.9091.. Test accuracy: 46.0000.. 0.1163 s/batch
# Epoch: 4/15.. Loss: 0.9889.. Test accuracy: 44.7500.. 0.0916 s/batch
# Epoch: 4/15.. Loss: 1.0009.. Test accuracy: 44.5000.. 0.0991 s/batch
# Epoch: 4/15.. Loss: 0.9761.. Test accuracy: 45.1875.. 0.1162 s/batch
# Epoch: 4/15.. Loss: 1.0064.. Test accuracy: 44.6875.. 0.0970 s/batch
# Epoch: 4/15.. Loss: 0.9513.. Test accuracy: 44.6875.. 0.1117 s/batch
# Epoch: 5/15.. Loss: 0.9802.. Test accuracy: 45.6250.. 0.0841 s/batch
# Epoch: 5/15.. Loss: 0.9017.. Test accuracy: 43.8125.. 0.1068 s/batch
# Epoch: 5/15.. Loss: 0.9628.. Test accuracy: 45.3750.. 0.1157 s/batch
# Epoch: 5/15.. Loss: 0.8395.. Test accuracy: 45.6875.. 0.0984 s/batch
# Epoch: 5/15.. Loss: 0.8764.. Test accuracy: 44.8750.. 0.1063 s/batch
# Epoch: 5/15.. Loss: 0.9175.. Test accuracy: 46.2500.. 0.0937 s/batch
# Epoch: 5/15.. Loss: 0.9007.. Test accuracy: 43.9375.. 0.0916 s/batch
# Epoch: 5/15.. Loss: 0.9463.. Test accuracy: 46.1250.. 0.1292 s/batch
# Epoch: 5/15.. Loss: 0.9159.. Test accuracy: 46.7500.. 0.0930 s/batch
# Epoch: 5/15.. Loss: 0.9016.. Test accuracy: 43.4375.. 0.0989 s/batch
# Epoch: 5/15.. Loss: 0.9108.. Test accuracy: 44.9375.. 0.1053 s/batch
# Epoch: 5/15.. Loss: 0.8968.. Test accuracy: 44.2500.. 0.0977 s/batch
# Epoch: 5/15.. Loss: 0.9404.. Test accuracy: 46.1875.. 0.1004 s/batch
# Epoch: 5/15.. Loss: 0.9209.. Test accuracy: 46.3125.. 0.1144 s/batch
# Epoch: 5/15.. Loss: 0.8770.. Test accuracy: 44.5000.. 0.0991 s/batch
# Epoch: 5/15.. Loss: 0.9111.. Test accuracy: 45.3750.. 0.1077 s/batch
# Epoch: 5/15.. Loss: 0.9630.. Test accuracy: 45.5000.. 0.1253 s/batch
# Epoch: 5/15.. Loss: 0.8750.. Test accuracy: 45.9375.. 0.1059 s/batch
# Epoch: 5/15.. Loss: 0.8639.. Test accuracy: 45.5625.. 0.0926 s/batch
# Epoch: 5/15.. Loss: 0.8692.. Test accuracy: 45.2500.. 0.1100 s/batch
# Epoch: 5/15.. Loss: 0.9090.. Test accuracy: 45.0000.. 0.1237 s/batch
# Epoch: 5/15.. Loss: 0.9578.. Test accuracy: 45.4375.. 0.1100 s/batch
# Epoch: 5/15.. Loss: 0.8686.. Test accuracy: 46.4375.. 0.1028 s/batch
# Epoch: 5/15.. Loss: 0.8955.. Test accuracy: 46.0000.. 0.1037 s/batch
# Epoch: 5/15.. Loss: 0.8844.. Test accuracy: 45.3750.. 0.1087 s/batch
# Epoch: 5/15.. Loss: 0.9184.. Test accuracy: 44.5625.. 0.1277 s/batch
# Epoch: 5/15.. Loss: 0.9495.. Test accuracy: 43.0000.. 0.1177 s/batch
# Epoch: 5/15.. Loss: 0.9611.. Test accuracy: 46.6875.. 0.1104 s/batch
# Epoch: 5/15.. Loss: 0.9154.. Test accuracy: 45.6875.. 0.0890 s/batch
# Epoch: 5/15.. Loss: 0.9009.. Test accuracy: 43.6875.. 0.0971 s/batch
# Epoch: 5/15.. Loss: 0.8803.. Test accuracy: 46.8125.. 0.0978 s/batch
# Epoch: 5/15.. Loss: 0.8558.. Test accuracy: 46.0000.. 0.0902 s/batch
# Epoch: 5/15.. Loss: 0.9166.. Test accuracy: 45.6875.. 0.1065 s/batch
# Epoch: 5/15.. Loss: 0.9213.. Test accuracy: 46.7500.. 0.1063 s/batch
# Epoch: 5/15.. Loss: 0.9340.. Test accuracy: 47.1250.. 0.1144 s/batch
# Epoch: 5/15.. Loss: 0.8924.. Test accuracy: 45.8750.. 0.0948 s/batch
# Epoch: 5/15.. Loss: 0.8737.. Test accuracy: 45.3750.. 0.1174 s/batch
# Epoch: 5/15.. Loss: 0.9214.. Test accuracy: 46.5000.. 0.1034 s/batch
# Epoch: 6/15.. Loss: 0.8230.. Test accuracy: 46.5625.. 0.0581 s/batch
# Epoch: 6/15.. Loss: 0.8697.. Test accuracy: 46.6875.. 0.0996 s/batch
# Epoch: 6/15.. Loss: 0.8840.. Test accuracy: 47.3125.. 0.1054 s/batch
# Epoch: 6/15.. Loss: 0.8670.. Test accuracy: 46.2500.. 0.1126 s/batch
# Epoch: 6/15.. Loss: 0.8131.. Test accuracy: 47.6250.. 0.1017 s/batch
# Epoch: 6/15.. Loss: 0.8824.. Test accuracy: 44.4375.. 0.1173 s/batch
# Epoch: 6/15.. Loss: 0.9046.. Test accuracy: 46.4375.. 0.1107 s/batch
# Epoch: 6/15.. Loss: 0.8381.. Test accuracy: 47.1250.. 0.0982 s/batch
# Epoch: 6/15.. Loss: 0.8500.. Test accuracy: 46.6875.. 0.1190 s/batch
# Epoch: 6/15.. Loss: 0.8273.. Test accuracy: 46.4375.. 0.1011 s/batch
# Epoch: 6/15.. Loss: 0.8933.. Test accuracy: 46.5625.. 0.0984 s/batch
# Epoch: 6/15.. Loss: 0.8462.. Test accuracy: 46.1875.. 0.0968 s/batch
# Epoch: 6/15.. Loss: 0.8386.. Test accuracy: 46.1250.. 0.1012 s/batch
# Epoch: 6/15.. Loss: 0.8877.. Test accuracy: 46.0000.. 0.0987 s/batch
# Epoch: 6/15.. Loss: 0.8898.. Test accuracy: 46.2500.. 0.1103 s/batch
# Epoch: 6/15.. Loss: 0.8513.. Test accuracy: 47.3750.. 0.0924 s/batch
# Epoch: 6/15.. Loss: 0.8649.. Test accuracy: 45.7500.. 0.1084 s/batch
# Epoch: 6/15.. Loss: 0.8631.. Test accuracy: 46.3125.. 0.1031 s/batch
# Epoch: 6/15.. Loss: 0.8705.. Test accuracy: 45.8125.. 0.1146 s/batch
# Epoch: 6/15.. Loss: 0.7802.. Test accuracy: 47.0625.. 0.0992 s/batch
# Epoch: 6/15.. Loss: 0.8126.. Test accuracy: 47.0000.. 0.0994 s/batch
# Epoch: 6/15.. Loss: 0.8606.. Test accuracy: 47.0000.. 0.1129 s/batch
# Epoch: 6/15.. Loss: 0.8620.. Test accuracy: 46.5625.. 0.1133 s/batch
# Epoch: 6/15.. Loss: 0.8041.. Test accuracy: 47.8750.. 0.1007 s/batch
# Epoch: 6/15.. Loss: 0.8484.. Test accuracy: 47.1250.. 0.1101 s/batch
# Epoch: 6/15.. Loss: 0.8221.. Test accuracy: 48.0000.. 0.1133 s/batch
# Epoch: 6/15.. Loss: 0.8533.. Test accuracy: 46.1250.. 0.1104 s/batch
# Epoch: 6/15.. Loss: 0.8596.. Test accuracy: 46.5625.. 0.0936 s/batch
# Epoch: 6/15.. Loss: 0.8113.. Test accuracy: 47.1875.. 0.1119 s/batch
# Epoch: 6/15.. Loss: 0.8219.. Test accuracy: 47.3125.. 0.1185 s/batch
# Epoch: 6/15.. Loss: 0.8413.. Test accuracy: 46.3750.. 0.1014 s/batch
# Epoch: 6/15.. Loss: 0.8326.. Test accuracy: 47.8750.. 0.0972 s/batch
# Epoch: 6/15.. Loss: 0.7928.. Test accuracy: 46.9375.. 0.1020 s/batch
# Epoch: 6/15.. Loss: 0.8604.. Test accuracy: 47.4375.. 0.0924 s/batch
# Epoch: 6/15.. Loss: 0.8871.. Test accuracy: 47.0625.. 0.0984 s/batch
# Epoch: 6/15.. Loss: 0.8147.. Test accuracy: 47.4375.. 0.1098 s/batch
# Epoch: 6/15.. Loss: 0.8336.. Test accuracy: 46.3125.. 0.1122 s/batch
# Epoch: 6/15.. Loss: 0.8930.. Test accuracy: 48.1875.. 0.1106 s/batch
# Epoch: 7/15.. Loss: 0.8435.. Test accuracy: 48.0000.. 0.0345 s/batch
# Epoch: 7/15.. Loss: 0.8324.. Test accuracy: 46.9375.. 0.1027 s/batch
# Epoch: 7/15.. Loss: 0.8130.. Test accuracy: 48.5625.. 0.1044 s/batch
# Epoch: 7/15.. Loss: 0.8032.. Test accuracy: 47.0000.. 0.1018 s/batch
# Epoch: 7/15.. Loss: 0.8017.. Test accuracy: 46.9375.. 0.1162 s/batch
# Epoch: 7/15.. Loss: 0.7733.. Test accuracy: 47.9375.. 0.1105 s/batch
# Epoch: 7/15.. Loss: 0.7834.. Test accuracy: 48.3750.. 0.1286 s/batch
# Epoch: 7/15.. Loss: 0.7847.. Test accuracy: 47.8750.. 0.0930 s/batch
# Epoch: 7/15.. Loss: 0.7940.. Test accuracy: 47.0625.. 0.1056 s/batch
# Epoch: 7/15.. Loss: 0.7706.. Test accuracy: 47.3125.. 0.0934 s/batch
# Epoch: 7/15.. Loss: 0.8612.. Test accuracy: 47.3125.. 0.1089 s/batch
# Epoch: 7/15.. Loss: 0.8174.. Test accuracy: 48.1875.. 0.0910 s/batch
# Epoch: 7/15.. Loss: 0.8373.. Test accuracy: 47.8750.. 0.1048 s/batch
# Epoch: 7/15.. Loss: 0.8594.. Test accuracy: 48.8125.. 0.1182 s/batch
# Epoch: 7/15.. Loss: 0.7760.. Test accuracy: 47.4375.. 0.1066 s/batch
# Epoch: 7/15.. Loss: 0.8270.. Test accuracy: 47.5000.. 0.1042 s/batch
# Epoch: 7/15.. Loss: 0.7527.. Test accuracy: 47.3125.. 0.1138 s/batch
# Epoch: 7/15.. Loss: 0.8025.. Test accuracy: 47.0000.. 0.1029 s/batch
# Epoch: 7/15.. Loss: 0.7658.. Test accuracy: 48.1875.. 0.1157 s/batch
# Epoch: 7/15.. Loss: 0.8609.. Test accuracy: 47.0000.. 0.1057 s/batch
# Epoch: 7/15.. Loss: 0.8288.. Test accuracy: 47.2500.. 0.1143 s/batch
# Epoch: 7/15.. Loss: 0.7791.. Test accuracy: 47.4375.. 0.0979 s/batch
# Epoch: 7/15.. Loss: 0.7831.. Test accuracy: 47.3750.. 0.0988 s/batch
# Epoch: 7/15.. Loss: 0.7673.. Test accuracy: 47.5625.. 0.1075 s/batch
# Epoch: 7/15.. Loss: 0.8672.. Test accuracy: 47.6250.. 0.0996 s/batch
# Epoch: 7/15.. Loss: 0.7442.. Test accuracy: 48.2500.. 0.1146 s/batch
# Epoch: 7/15.. Loss: 0.7818.. Test accuracy: 48.0625.. 0.1160 s/batch
# Epoch: 7/15.. Loss: 0.8048.. Test accuracy: 47.9375.. 0.1066 s/batch
# Epoch: 7/15.. Loss: 0.7709.. Test accuracy: 47.0000.. 0.1023 s/batch
# Epoch: 7/15.. Loss: 0.8022.. Test accuracy: 46.6250.. 0.1139 s/batch
# Epoch: 7/15.. Loss: 0.7828.. Test accuracy: 47.9375.. 0.1150 s/batch
# Epoch: 7/15.. Loss: 0.8383.. Test accuracy: 47.6875.. 0.1079 s/batch
# Epoch: 7/15.. Loss: 0.7890.. Test accuracy: 48.6250.. 0.1161 s/batch
# Epoch: 7/15.. Loss: 0.7749.. Test accuracy: 47.5000.. 0.1155 s/batch
# Epoch: 7/15.. Loss: 0.7861.. Test accuracy: 48.6250.. 0.1056 s/batch
# Epoch: 7/15.. Loss: 0.7930.. Test accuracy: 48.1875.. 0.1340 s/batch
# Epoch: 7/15.. Loss: 0.7742.. Test accuracy: 48.0000.. 0.1032 s/batch
# Epoch: 7/15.. Loss: 0.8543.. Test accuracy: 49.0625.. 0.1103 s/batch
# Epoch: 7/15.. Loss: 0.7827.. Test accuracy: 48.5000.. 0.0895 s/batch
# Epoch: 8/15.. Loss: 0.7705.. Test accuracy: 48.4375.. 0.1227 s/batch
# Epoch: 8/15.. Loss: 0.7960.. Test accuracy: 48.3125.. 0.1034 s/batch
# Epoch: 8/15.. Loss: 0.7139.. Test accuracy: 48.7500.. 0.1040 s/batch
# Epoch: 8/15.. Loss: 0.7862.. Test accuracy: 48.5000.. 0.1101 s/batch
# Epoch: 8/15.. Loss: 0.7812.. Test accuracy: 48.2500.. 0.1056 s/batch
# Epoch: 8/15.. Loss: 0.7697.. Test accuracy: 46.8125.. 0.1098 s/batch
# Epoch: 8/15.. Loss: 0.7625.. Test accuracy: 48.2500.. 0.1183 s/batch
# Epoch: 8/15.. Loss: 0.7693.. Test accuracy: 47.5000.. 0.1018 s/batch
# Epoch: 8/15.. Loss: 0.7344.. Test accuracy: 48.2500.. 0.1163 s/batch
# Epoch: 8/15.. Loss: 0.7457.. Test accuracy: 49.4375.. 0.0979 s/batch
# Epoch: 8/15.. Loss: 0.7717.. Test accuracy: 47.7500.. 0.1100 s/batch
# Epoch: 8/15.. Loss: 0.7575.. Test accuracy: 49.1250.. 0.1182 s/batch
# Epoch: 8/15.. Loss: 0.7520.. Test accuracy: 48.8125.. 0.1174 s/batch
# Epoch: 8/15.. Loss: 0.7622.. Test accuracy: 48.2500.. 0.1097 s/batch
# Epoch: 8/15.. Loss: 0.7651.. Test accuracy: 48.6875.. 0.1076 s/batch
# Epoch: 8/15.. Loss: 0.6947.. Test accuracy: 47.8750.. 0.1015 s/batch
# Epoch: 8/15.. Loss: 0.7378.. Test accuracy: 48.8750.. 0.0984 s/batch
# Epoch: 8/15.. Loss: 0.7212.. Test accuracy: 48.8750.. 0.1063 s/batch
# Epoch: 8/15.. Loss: 0.7349.. Test accuracy: 48.4375.. 0.1051 s/batch
# Epoch: 8/15.. Loss: 0.7700.. Test accuracy: 49.2500.. 0.1212 s/batch
# Epoch: 8/15.. Loss: 0.7614.. Test accuracy: 49.8750.. 0.1118 s/batch
# Epoch: 8/15.. Loss: 0.8090.. Test accuracy: 48.7500.. 0.1037 s/batch
# Epoch: 8/15.. Loss: 0.7684.. Test accuracy: 48.7500.. 0.1002 s/batch
# Epoch: 8/15.. Loss: 0.7761.. Test accuracy: 48.6250.. 0.1070 s/batch
# Epoch: 8/15.. Loss: 0.6773.. Test accuracy: 48.9375.. 0.1138 s/batch
# Epoch: 8/15.. Loss: 0.7915.. Test accuracy: 48.6250.. 0.1049 s/batch
# Epoch: 8/15.. Loss: 0.7427.. Test accuracy: 47.7500.. 0.1100 s/batch
# Epoch: 8/15.. Loss: 0.7814.. Test accuracy: 47.6875.. 0.1041 s/batch
# Epoch: 8/15.. Loss: 0.7169.. Test accuracy: 49.3125.. 0.1011 s/batch
# Epoch: 8/15.. Loss: 0.7537.. Test accuracy: 48.3125.. 0.1031 s/batch
# Epoch: 8/15.. Loss: 0.7351.. Test accuracy: 48.4375.. 0.1000 s/batch
# Epoch: 8/15.. Loss: 0.8080.. Test accuracy: 47.9375.. 0.0936 s/batch
# Epoch: 8/15.. Loss: 0.7755.. Test accuracy: 49.6875.. 0.1090 s/batch
# Epoch: 8/15.. Loss: 0.8328.. Test accuracy: 48.5625.. 0.1148 s/batch
# Epoch: 8/15.. Loss: 0.7797.. Test accuracy: 48.8750.. 0.1002 s/batch
# Epoch: 8/15.. Loss: 0.7477.. Test accuracy: 48.5625.. 0.1045 s/batch
# Epoch: 8/15.. Loss: 0.8174.. Test accuracy: 48.8750.. 0.1094 s/batch
# Epoch: 8/15.. Loss: 0.7671.. Test accuracy: 48.8750.. 0.1275 s/batch
# Epoch: 9/15.. Loss: 0.7245.. Test accuracy: 48.0000.. 0.0820 s/batch
# Epoch: 9/15.. Loss: 0.7155.. Test accuracy: 48.1250.. 0.1057 s/batch
# Epoch: 9/15.. Loss: 0.7065.. Test accuracy: 49.0625.. 0.1183 s/batch
# Epoch: 9/15.. Loss: 0.7325.. Test accuracy: 47.8750.. 0.0957 s/batch
# Epoch: 9/15.. Loss: 0.7679.. Test accuracy: 49.3125.. 0.1037 s/batch
# Epoch: 9/15.. Loss: 0.7327.. Test accuracy: 49.3750.. 0.1084 s/batch
# Epoch: 9/15.. Loss: 0.7369.. Test accuracy: 49.5000.. 0.1254 s/batch
# Epoch: 9/15.. Loss: 0.7191.. Test accuracy: 49.6875.. 0.1279 s/batch
# Epoch: 9/15.. Loss: 0.7156.. Test accuracy: 48.8750.. 0.1078 s/batch
# Epoch: 9/15.. Loss: 0.7266.. Test accuracy: 49.4375.. 0.1003 s/batch
# Epoch: 9/15.. Loss: 0.6738.. Test accuracy: 48.7500.. 0.1059 s/batch
# Epoch: 9/15.. Loss: 0.8020.. Test accuracy: 50.2500.. 0.1050 s/batch
# Epoch: 9/15.. Loss: 0.7825.. Test accuracy: 48.7500.. 0.0985 s/batch
# Epoch: 9/15.. Loss: 0.7202.. Test accuracy: 49.5000.. 0.1061 s/batch
# Epoch: 9/15.. Loss: 0.7206.. Test accuracy: 49.6250.. 0.1149 s/batch
# Epoch: 9/15.. Loss: 0.7712.. Test accuracy: 49.3750.. 0.1137 s/batch
# Epoch: 9/15.. Loss: 0.7094.. Test accuracy: 49.2500.. 0.1017 s/batch
# Epoch: 9/15.. Loss: 0.7483.. Test accuracy: 48.8750.. 0.1032 s/batch
# Epoch: 9/15.. Loss: 0.7129.. Test accuracy: 48.6250.. 0.1055 s/batch
# Epoch: 9/15.. Loss: 0.7238.. Test accuracy: 49.1250.. 0.1253 s/batch
# Epoch: 9/15.. Loss: 0.7271.. Test accuracy: 49.0000.. 0.1160 s/batch
# Epoch: 9/15.. Loss: 0.7315.. Test accuracy: 48.8125.. 0.1089 s/batch
# Epoch: 9/15.. Loss: 0.7254.. Test accuracy: 49.1250.. 0.1248 s/batch
# Epoch: 9/15.. Loss: 0.7649.. Test accuracy: 48.7500.. 0.1053 s/batch
# Epoch: 9/15.. Loss: 0.7116.. Test accuracy: 49.5000.. 0.0929 s/batch
# Epoch: 9/15.. Loss: 0.7204.. Test accuracy: 48.4375.. 0.0944 s/batch
# Epoch: 9/15.. Loss: 0.6862.. Test accuracy: 49.3750.. 0.1250 s/batch
# Epoch: 9/15.. Loss: 0.7202.. Test accuracy: 48.5625.. 0.1112 s/batch
# Epoch: 9/15.. Loss: 0.7254.. Test accuracy: 48.9375.. 0.1135 s/batch
# Epoch: 9/15.. Loss: 0.7117.. Test accuracy: 49.6875.. 0.1135 s/batch
# Epoch: 9/15.. Loss: 0.7264.. Test accuracy: 49.2500.. 0.1119 s/batch
# Epoch: 9/15.. Loss: 0.7243.. Test accuracy: 49.2500.. 0.1025 s/batch
# Epoch: 9/15.. Loss: 0.7215.. Test accuracy: 49.3750.. 0.0988 s/batch
# Epoch: 9/15.. Loss: 0.7504.. Test accuracy: 49.3750.. 0.1000 s/batch
# Epoch: 9/15.. Loss: 0.7635.. Test accuracy: 50.3125.. 0.1361 s/batch
# Epoch: 9/15.. Loss: 0.7237.. Test accuracy: 49.1875.. 0.1121 s/batch
# Epoch: 9/15.. Loss: 0.6990.. Test accuracy: 48.8750.. 0.1114 s/batch
# Epoch: 9/15.. Loss: 0.7387.. Test accuracy: 50.2500.. 0.1026 s/batch
# Epoch: 10/15.. Loss: 0.6763.. Test accuracy: 49.7500.. 0.0430 s/batch
# Epoch: 10/15.. Loss: 0.6714.. Test accuracy: 50.0625.. 0.1144 s/batch
# Epoch: 10/15.. Loss: 0.7341.. Test accuracy: 49.5625.. 0.1023 s/batch
# Epoch: 10/15.. Loss: 0.7362.. Test accuracy: 49.9375.. 0.1013 s/batch
# Epoch: 10/15.. Loss: 0.6692.. Test accuracy: 49.3125.. 0.1116 s/batch
# Epoch: 10/15.. Loss: 0.6720.. Test accuracy: 49.8125.. 0.1003 s/batch
# Epoch: 10/15.. Loss: 0.7343.. Test accuracy: 49.3750.. 0.1143 s/batch
# Epoch: 10/15.. Loss: 0.7341.. Test accuracy: 48.9375.. 0.1108 s/batch
# Epoch: 10/15.. Loss: 0.7008.. Test accuracy: 49.6875.. 0.0978 s/batch
# Epoch: 10/15.. Loss: 0.7553.. Test accuracy: 50.6250.. 0.1100 s/batch
# Epoch: 10/15.. Loss: 0.7044.. Test accuracy: 50.3125.. 0.0915 s/batch
# Epoch: 10/15.. Loss: 0.6328.. Test accuracy: 50.4375.. 0.1141 s/batch
# Epoch: 10/15.. Loss: 0.7383.. Test accuracy: 49.8750.. 0.1052 s/batch
# Epoch: 10/15.. Loss: 0.6835.. Test accuracy: 49.7500.. 0.0947 s/batch
# Epoch: 10/15.. Loss: 0.6890.. Test accuracy: 50.0000.. 0.0965 s/batch
# Epoch: 10/15.. Loss: 0.7219.. Test accuracy: 50.5000.. 0.1137 s/batch
# Epoch: 10/15.. Loss: 0.6660.. Test accuracy: 50.3750.. 0.1104 s/batch
# Epoch: 10/15.. Loss: 0.7147.. Test accuracy: 50.1250.. 0.1159 s/batch
# Epoch: 10/15.. Loss: 0.6925.. Test accuracy: 50.3125.. 0.1096 s/batch
# Epoch: 10/15.. Loss: 0.6524.. Test accuracy: 49.6875.. 0.1009 s/batch
# Epoch: 10/15.. Loss: 0.7220.. Test accuracy: 49.6250.. 0.0920 s/batch
# Epoch: 10/15.. Loss: 0.6563.. Test accuracy: 49.4375.. 0.1128 s/batch
# Epoch: 10/15.. Loss: 0.6965.. Test accuracy: 49.1250.. 0.1013 s/batch
# Epoch: 10/15.. Loss: 0.7062.. Test accuracy: 50.5000.. 0.1189 s/batch
# Epoch: 10/15.. Loss: 0.7008.. Test accuracy: 49.6250.. 0.1129 s/batch
# Epoch: 10/15.. Loss: 0.6977.. Test accuracy: 49.9375.. 0.0980 s/batch
# Epoch: 10/15.. Loss: 0.7303.. Test accuracy: 49.7500.. 0.1092 s/batch
# Epoch: 10/15.. Loss: 0.6463.. Test accuracy: 49.2500.. 0.0982 s/batch
# Epoch: 10/15.. Loss: 0.6646.. Test accuracy: 49.7500.. 0.1149 s/batch
# Epoch: 10/15.. Loss: 0.7120.. Test accuracy: 50.0000.. 0.1206 s/batch
# Epoch: 10/15.. Loss: 0.6585.. Test accuracy: 49.3125.. 0.1160 s/batch
# Epoch: 10/15.. Loss: 0.6944.. Test accuracy: 50.5625.. 0.1163 s/batch
# Epoch: 10/15.. Loss: 0.6866.. Test accuracy: 50.5000.. 0.1125 s/batch
# Epoch: 10/15.. Loss: 0.6702.. Test accuracy: 49.6875.. 0.1160 s/batch
# Epoch: 10/15.. Loss: 0.7350.. Test accuracy: 50.0625.. 0.1147 s/batch
# Epoch: 10/15.. Loss: 0.6925.. Test accuracy: 50.2500.. 0.1256 s/batch
# Epoch: 10/15.. Loss: 0.6412.. Test accuracy: 49.0000.. 0.1071 s/batch
# Epoch: 10/15.. Loss: 0.7667.. Test accuracy: 49.6875.. 0.1088 s/batch
# Epoch: 10/15.. Loss: 0.7146.. Test accuracy: 49.5625.. 0.0793 s/batch
# Epoch: 11/15.. Loss: 0.6985.. Test accuracy: 49.1250.. 0.1041 s/batch
# Epoch: 11/15.. Loss: 0.6557.. Test accuracy: 49.9375.. 0.1123 s/batch
# Epoch: 11/15.. Loss: 0.5878.. Test accuracy: 50.0625.. 0.1260 s/batch
# Epoch: 11/15.. Loss: 0.6832.. Test accuracy: 49.6250.. 0.1064 s/batch
# Epoch: 11/15.. Loss: 0.6609.. Test accuracy: 50.1875.. 0.0999 s/batch
# Epoch: 11/15.. Loss: 0.6408.. Test accuracy: 49.1875.. 0.0993 s/batch
# Epoch: 11/15.. Loss: 0.6839.. Test accuracy: 50.3125.. 0.0968 s/batch
# Epoch: 11/15.. Loss: 0.6206.. Test accuracy: 50.0000.. 0.1061 s/batch
# Epoch: 11/15.. Loss: 0.6323.. Test accuracy: 49.7500.. 0.1211 s/batch
# Epoch: 11/15.. Loss: 0.7238.. Test accuracy: 49.7500.. 0.1040 s/batch
# Epoch: 11/15.. Loss: 0.7169.. Test accuracy: 50.1875.. 0.0993 s/batch
# Epoch: 11/15.. Loss: 0.6737.. Test accuracy: 50.1250.. 0.1138 s/batch
# Epoch: 11/15.. Loss: 0.6664.. Test accuracy: 50.0000.. 0.0950 s/batch
# Epoch: 11/15.. Loss: 0.7099.. Test accuracy: 50.1875.. 0.1129 s/batch
# Epoch: 11/15.. Loss: 0.7045.. Test accuracy: 50.8125.. 0.1191 s/batch
# Epoch: 11/15.. Loss: 0.6514.. Test accuracy: 50.3750.. 0.1141 s/batch
# Epoch: 11/15.. Loss: 0.7002.. Test accuracy: 50.1250.. 0.1189 s/batch
# Epoch: 11/15.. Loss: 0.6458.. Test accuracy: 49.1875.. 0.1164 s/batch
# Epoch: 11/15.. Loss: 0.6407.. Test accuracy: 50.0000.. 0.1141 s/batch
# Epoch: 11/15.. Loss: 0.6542.. Test accuracy: 50.1875.. 0.0978 s/batch
# Epoch: 11/15.. Loss: 0.6500.. Test accuracy: 50.3125.. 0.1177 s/batch
# Epoch: 11/15.. Loss: 0.7131.. Test accuracy: 50.4375.. 0.1047 s/batch
# Epoch: 11/15.. Loss: 0.6932.. Test accuracy: 50.0625.. 0.0950 s/batch
# Epoch: 11/15.. Loss: 0.6386.. Test accuracy: 50.5000.. 0.0995 s/batch
# Epoch: 11/15.. Loss: 0.6853.. Test accuracy: 50.4375.. 0.1172 s/batch
# Epoch: 11/15.. Loss: 0.6661.. Test accuracy: 50.4375.. 0.1091 s/batch
# Epoch: 11/15.. Loss: 0.6979.. Test accuracy: 49.9375.. 0.1044 s/batch
# Epoch: 11/15.. Loss: 0.6803.. Test accuracy: 50.9375.. 0.1082 s/batch
# Epoch: 11/15.. Loss: 0.6071.. Test accuracy: 50.1250.. 0.1077 s/batch
# Epoch: 11/15.. Loss: 0.6776.. Test accuracy: 49.7500.. 0.1176 s/batch
# Epoch: 11/15.. Loss: 0.7029.. Test accuracy: 49.5000.. 0.1025 s/batch
# Epoch: 11/15.. Loss: 0.7052.. Test accuracy: 50.8125.. 0.1088 s/batch
# Epoch: 11/15.. Loss: 0.6376.. Test accuracy: 50.5000.. 0.1196 s/batch
# Epoch: 11/15.. Loss: 0.6645.. Test accuracy: 49.8750.. 0.1078 s/batch
# Epoch: 11/15.. Loss: 0.7118.. Test accuracy: 49.6875.. 0.1215 s/batch
# Epoch: 11/15.. Loss: 0.6594.. Test accuracy: 50.5000.. 0.0994 s/batch
# Epoch: 11/15.. Loss: 0.6537.. Test accuracy: 50.0000.. 0.1038 s/batch
# Epoch: 11/15.. Loss: 0.6391.. Test accuracy: 50.6875.. 0.0919 s/batch
# Epoch: 12/15.. Loss: 0.6797.. Test accuracy: 50.6250.. 0.0879 s/batch
# Epoch: 12/15.. Loss: 0.6462.. Test accuracy: 50.5625.. 0.1213 s/batch
# Epoch: 12/15.. Loss: 0.6567.. Test accuracy: 51.0625.. 0.1090 s/batch
# Epoch: 12/15.. Loss: 0.6662.. Test accuracy: 51.0625.. 0.1215 s/batch
# Epoch: 12/15.. Loss: 0.6612.. Test accuracy: 50.4375.. 0.0976 s/batch
# Epoch: 12/15.. Loss: 0.6303.. Test accuracy: 50.8750.. 0.0976 s/batch
# Epoch: 12/15.. Loss: 0.6499.. Test accuracy: 50.8125.. 0.0993 s/batch
# Epoch: 12/15.. Loss: 0.6695.. Test accuracy: 51.1250.. 0.1098 s/batch
# Epoch: 12/15.. Loss: 0.6815.. Test accuracy: 50.6875.. 0.1018 s/batch
# Epoch: 12/15.. Loss: 0.6517.. Test accuracy: 51.0625.. 0.1228 s/batch
# Epoch: 12/15.. Loss: 0.6703.. Test accuracy: 50.8125.. 0.1184 s/batch
# Epoch: 12/15.. Loss: 0.6537.. Test accuracy: 50.7500.. 0.1141 s/batch
# Epoch: 12/15.. Loss: 0.6124.. Test accuracy: 50.1250.. 0.1123 s/batch
# Epoch: 12/15.. Loss: 0.6206.. Test accuracy: 51.1250.. 0.1200 s/batch
# Epoch: 12/15.. Loss: 0.6459.. Test accuracy: 51.0000.. 0.1193 s/batch
# Epoch: 12/15.. Loss: 0.6319.. Test accuracy: 50.6250.. 0.1119 s/batch
# Epoch: 12/15.. Loss: 0.6173.. Test accuracy: 51.0625.. 0.1023 s/batch
# Epoch: 12/15.. Loss: 0.6794.. Test accuracy: 50.7500.. 0.1170 s/batch
# Epoch: 12/15.. Loss: 0.6197.. Test accuracy: 51.7500.. 0.1194 s/batch
# Epoch: 12/15.. Loss: 0.6851.. Test accuracy: 51.3750.. 0.1047 s/batch
# Epoch: 12/15.. Loss: 0.6904.. Test accuracy: 50.1250.. 0.1089 s/batch
# Epoch: 12/15.. Loss: 0.6127.. Test accuracy: 50.2500.. 0.1019 s/batch
# Epoch: 12/15.. Loss: 0.6475.. Test accuracy: 50.8750.. 0.1089 s/batch
# Epoch: 12/15.. Loss: 0.6934.. Test accuracy: 50.8125.. 0.1077 s/batch
# Epoch: 12/15.. Loss: 0.6562.. Test accuracy: 50.8125.. 0.1080 s/batch
# Epoch: 12/15.. Loss: 0.6673.. Test accuracy: 50.5625.. 0.1122 s/batch
# Epoch: 12/15.. Loss: 0.6275.. Test accuracy: 50.1250.. 0.1189 s/batch
# Epoch: 12/15.. Loss: 0.6359.. Test accuracy: 50.6875.. 0.1109 s/batch
# Epoch: 12/15.. Loss: 0.6402.. Test accuracy: 50.8125.. 0.1080 s/batch
# Epoch: 12/15.. Loss: 0.6413.. Test accuracy: 50.3125.. 0.1079 s/batch
# Epoch: 12/15.. Loss: 0.6182.. Test accuracy: 50.5625.. 0.1293 s/batch
# Epoch: 12/15.. Loss: 0.6320.. Test accuracy: 50.9375.. 0.1165 s/batch
# Epoch: 12/15.. Loss: 0.6371.. Test accuracy: 50.3125.. 0.1163 s/batch
# Epoch: 12/15.. Loss: 0.6428.. Test accuracy: 50.3750.. 0.1072 s/batch
# Epoch: 12/15.. Loss: 0.6041.. Test accuracy: 50.5000.. 0.1140 s/batch
# Epoch: 12/15.. Loss: 0.6540.. Test accuracy: 50.4375.. 0.1051 s/batch
# Epoch: 12/15.. Loss: 0.6321.. Test accuracy: 50.9375.. 0.1075 s/batch
# Epoch: 12/15.. Loss: 0.6476.. Test accuracy: 50.3750.. 0.1092 s/batch
# Epoch: 13/15.. Loss: 0.6875.. Test accuracy: 50.6250.. 0.0533 s/batch
# Epoch: 13/15.. Loss: 0.6163.. Test accuracy: 51.0000.. 0.1078 s/batch
# Epoch: 13/15.. Loss: 0.5985.. Test accuracy: 50.9375.. 0.1177 s/batch
# Epoch: 13/15.. Loss: 0.6155.. Test accuracy: 50.7500.. 0.1167 s/batch
# Epoch: 13/15.. Loss: 0.6261.. Test accuracy: 50.6875.. 0.1055 s/batch
# Epoch: 13/15.. Loss: 0.6575.. Test accuracy: 50.9375.. 0.0990 s/batch
# Epoch: 13/15.. Loss: 0.6349.. Test accuracy: 50.9375.. 0.1112 s/batch
# Epoch: 13/15.. Loss: 0.6864.. Test accuracy: 51.1250.. 0.1112 s/batch
# Epoch: 13/15.. Loss: 0.6675.. Test accuracy: 51.4375.. 0.1068 s/batch
# Epoch: 13/15.. Loss: 0.6351.. Test accuracy: 51.1250.. 0.1004 s/batch
# Epoch: 13/15.. Loss: 0.6177.. Test accuracy: 50.8750.. 0.1018 s/batch
# Epoch: 13/15.. Loss: 0.6192.. Test accuracy: 50.3750.. 0.1039 s/batch
# Epoch: 13/15.. Loss: 0.6447.. Test accuracy: 50.5000.. 0.1168 s/batch
# Epoch: 13/15.. Loss: 0.6407.. Test accuracy: 50.6875.. 0.1242 s/batch
# Epoch: 13/15.. Loss: 0.5971.. Test accuracy: 50.8125.. 0.0984 s/batch
# Epoch: 13/15.. Loss: 0.5989.. Test accuracy: 50.8125.. 0.1057 s/batch
# Epoch: 13/15.. Loss: 0.6067.. Test accuracy: 51.1875.. 0.1116 s/batch
# Epoch: 13/15.. Loss: 0.6202.. Test accuracy: 50.8125.. 0.0948 s/batch
# Epoch: 13/15.. Loss: 0.6264.. Test accuracy: 50.9375.. 0.1124 s/batch
# Epoch: 13/15.. Loss: 0.6227.. Test accuracy: 50.4375.. 0.1067 s/batch
# Epoch: 13/15.. Loss: 0.6255.. Test accuracy: 51.0000.. 0.1048 s/batch
# Epoch: 13/15.. Loss: 0.6265.. Test accuracy: 50.9375.. 0.1198 s/batch
# Epoch: 13/15.. Loss: 0.6290.. Test accuracy: 50.8125.. 0.1081 s/batch
# Epoch: 13/15.. Loss: 0.6471.. Test accuracy: 50.7500.. 0.1184 s/batch
# Epoch: 13/15.. Loss: 0.6434.. Test accuracy: 50.5000.. 0.1237 s/batch
# Epoch: 13/15.. Loss: 0.6089.. Test accuracy: 51.3750.. 0.1191 s/batch
# Epoch: 13/15.. Loss: 0.6712.. Test accuracy: 51.3125.. 0.1110 s/batch
# Epoch: 13/15.. Loss: 0.6105.. Test accuracy: 51.4375.. 0.1103 s/batch
# Epoch: 13/15.. Loss: 0.6207.. Test accuracy: 51.4375.. 0.1228 s/batch
# Epoch: 13/15.. Loss: 0.6510.. Test accuracy: 50.8750.. 0.1160 s/batch
# Epoch: 13/15.. Loss: 0.6442.. Test accuracy: 50.8125.. 0.1182 s/batch
# Epoch: 13/15.. Loss: 0.5927.. Test accuracy: 50.5625.. 0.1106 s/batch
# Epoch: 13/15.. Loss: 0.6045.. Test accuracy: 51.0625.. 0.0952 s/batch
# Epoch: 13/15.. Loss: 0.6126.. Test accuracy: 51.1250.. 0.1076 s/batch
# Epoch: 13/15.. Loss: 0.6215.. Test accuracy: 50.8125.. 0.0980 s/batch
# Epoch: 13/15.. Loss: 0.5969.. Test accuracy: 51.0000.. 0.1171 s/batch
# Epoch: 13/15.. Loss: 0.6066.. Test accuracy: 51.1875.. 0.1146 s/batch
# Epoch: 13/15.. Loss: 0.6186.. Test accuracy: 51.4375.. 0.1151 s/batch
# Epoch: 14/15.. Loss: 0.6207.. Test accuracy: 51.1875.. 0.0211 s/batch
# Epoch: 14/15.. Loss: 0.5958.. Test accuracy: 51.0000.. 0.1256 s/batch
# Epoch: 14/15.. Loss: 0.5512.. Test accuracy: 51.3125.. 0.1067 s/batch
# Epoch: 14/15.. Loss: 0.6093.. Test accuracy: 51.3125.. 0.1356 s/batch
# Epoch: 14/15.. Loss: 0.6384.. Test accuracy: 50.7500.. 0.1153 s/batch
# Epoch: 14/15.. Loss: 0.6048.. Test accuracy: 51.0625.. 0.1130 s/batch
# Epoch: 14/15.. Loss: 0.6157.. Test accuracy: 51.4375.. 0.1170 s/batch
# Epoch: 14/15.. Loss: 0.6442.. Test accuracy: 51.3750.. 0.1227 s/batch
# Epoch: 14/15.. Loss: 0.5717.. Test accuracy: 50.9375.. 0.1055 s/batch
# Epoch: 14/15.. Loss: 0.6139.. Test accuracy: 51.0625.. 0.1199 s/batch
# Epoch: 14/15.. Loss: 0.6065.. Test accuracy: 51.1875.. 0.1026 s/batch
# Epoch: 14/15.. Loss: 0.6171.. Test accuracy: 51.2500.. 0.1058 s/batch
# Epoch: 14/15.. Loss: 0.6506.. Test accuracy: 51.3750.. 0.1122 s/batch
# Epoch: 14/15.. Loss: 0.6308.. Test accuracy: 51.0625.. 0.1037 s/batch
# Epoch: 14/15.. Loss: 0.5817.. Test accuracy: 51.0625.. 0.0991 s/batch
# Epoch: 14/15.. Loss: 0.5863.. Test accuracy: 51.3750.. 0.1051 s/batch
# Epoch: 14/15.. Loss: 0.6326.. Test accuracy: 51.1250.. 0.1019 s/batch
# Epoch: 14/15.. Loss: 0.5969.. Test accuracy: 51.2500.. 0.1102 s/batch
# Epoch: 14/15.. Loss: 0.5827.. Test accuracy: 51.2500.. 0.1163 s/batch
# Epoch: 14/15.. Loss: 0.6158.. Test accuracy: 51.3125.. 0.1036 s/batch
# Epoch: 14/15.. Loss: 0.6326.. Test accuracy: 51.1250.. 0.1097 s/batch
# Epoch: 14/15.. Loss: 0.5916.. Test accuracy: 50.8750.. 0.1005 s/batch
# Epoch: 14/15.. Loss: 0.6277.. Test accuracy: 50.8750.. 0.1163 s/batch
# Epoch: 14/15.. Loss: 0.5981.. Test accuracy: 51.3125.. 0.1058 s/batch
# Epoch: 14/15.. Loss: 0.6059.. Test accuracy: 51.1875.. 0.0996 s/batch
# Epoch: 14/15.. Loss: 0.5742.. Test accuracy: 51.0625.. 0.0983 s/batch
# Epoch: 14/15.. Loss: 0.6367.. Test accuracy: 51.2500.. 0.1156 s/batch
# Epoch: 14/15.. Loss: 0.6692.. Test accuracy: 50.7500.. 0.1084 s/batch
# Epoch: 14/15.. Loss: 0.6542.. Test accuracy: 50.6875.. 0.0965 s/batch
# Epoch: 14/15.. Loss: 0.6615.. Test accuracy: 51.0625.. 0.0983 s/batch
# Epoch: 14/15.. Loss: 0.6371.. Test accuracy: 51.0625.. 0.0986 s/batch
# Epoch: 14/15.. Loss: 0.6285.. Test accuracy: 51.2500.. 0.1096 s/batch
# Epoch: 14/15.. Loss: 0.6011.. Test accuracy: 51.2500.. 0.1056 s/batch
# Epoch: 14/15.. Loss: 0.6117.. Test accuracy: 51.4375.. 0.0961 s/batch
# Epoch: 14/15.. Loss: 0.6063.. Test accuracy: 51.3125.. 0.0978 s/batch
# Epoch: 14/15.. Loss: 0.6490.. Test accuracy: 51.1250.. 0.1255 s/batch
# Epoch: 14/15.. Loss: 0.6228.. Test accuracy: 50.5625.. 0.1109 s/batch
# Epoch: 14/15.. Loss: 0.5825.. Test accuracy: 50.7500.. 0.1240 s/batch
# Epoch: 14/15.. Loss: 0.6096.. Test accuracy: 51.2500.. 0.0978 s/batch
# Epoch: 15/15.. Loss: 0.6298.. Test accuracy: 51.5000.. 0.1068 s/batch
# Epoch: 15/15.. Loss: 0.5974.. Test accuracy: 51.1250.. 0.1068 s/batch
# Epoch: 15/15.. Loss: 0.5835.. Test accuracy: 51.5000.. 0.1117 s/batch
# Epoch: 15/15.. Loss: 0.6456.. Test accuracy: 51.1875.. 0.1072 s/batch
# Epoch: 15/15.. Loss: 0.5750.. Test accuracy: 51.3750.. 0.1234 s/batch
# Epoch: 15/15.. Loss: 0.5994.. Test accuracy: 51.0000.. 0.1346 s/batch
# Epoch: 15/15.. Loss: 0.5841.. Test accuracy: 51.1250.. 0.1040 s/batch
# Epoch: 15/15.. Loss: 0.6514.. Test accuracy: 51.2500.. 0.1082 s/batch
# Epoch: 15/15.. Loss: 0.6034.. Test accuracy: 51.1250.. 0.1085 s/batch
# Epoch: 15/15.. Loss: 0.6548.. Test accuracy: 51.5000.. 0.1021 s/batch
# Epoch: 15/15.. Loss: 0.6210.. Test accuracy: 51.1250.. 0.1131 s/batch
# Epoch: 15/15.. Loss: 0.5950.. Test accuracy: 51.5625.. 0.0964 s/batch
# Epoch: 15/15.. Loss: 0.5830.. Test accuracy: 51.3125.. 0.1091 s/batch
# Epoch: 15/15.. Loss: 0.6408.. Test accuracy: 51.5625.. 0.1036 s/batch
# Epoch: 15/15.. Loss: 0.6133.. Test accuracy: 51.4375.. 0.1131 s/batch
# Epoch: 15/15.. Loss: 0.6306.. Test accuracy: 51.3750.. 0.1210 s/batch
# Epoch: 15/15.. Loss: 0.5849.. Test accuracy: 51.0625.. 0.0993 s/batch
# Epoch: 15/15.. Loss: 0.5794.. Test accuracy: 51.2500.. 0.1042 s/batch
# Epoch: 15/15.. Loss: 0.6195.. Test accuracy: 51.5000.. 0.1026 s/batch
# Epoch: 15/15.. Loss: 0.6298.. Test accuracy: 51.4375.. 0.1016 s/batch
# Epoch: 15/15.. Loss: 0.5918.. Test accuracy: 51.6875.. 0.1037 s/batch
# Epoch: 15/15.. Loss: 0.5723.. Test accuracy: 51.5000.. 0.1119 s/batch
# Epoch: 15/15.. Loss: 0.6318.. Test accuracy: 51.5625.. 0.1176 s/batch
# Epoch: 15/15.. Loss: 0.6240.. Test accuracy: 51.2500.. 0.1027 s/batch
# Epoch: 15/15.. Loss: 0.5812.. Test accuracy: 51.4375.. 0.1033 s/batch
# Epoch: 15/15.. Loss: 0.5903.. Test accuracy: 51.3125.. 0.1311 s/batch
# Epoch: 15/15.. Loss: 0.6086.. Test accuracy: 51.3125.. 0.1144 s/batch
# Epoch: 15/15.. Loss: 0.5790.. Test accuracy: 51.6250.. 0.1267 s/batch
# Epoch: 15/15.. Loss: 0.5769.. Test accuracy: 51.6875.. 0.1146 s/batch
# Epoch: 15/15.. Loss: 0.6041.. Test accuracy: 51.5000.. 0.1026 s/batch
# Epoch: 15/15.. Loss: 0.6532.. Test accuracy: 51.2500.. 0.1226 s/batch
# Epoch: 15/15.. Loss: 0.6427.. Test accuracy: 51.4375.. 0.1010 s/batch
# Epoch: 15/15.. Loss: 0.6387.. Test accuracy: 51.5000.. 0.1229 s/batch
# Epoch: 15/15.. Loss: 0.6229.. Test accuracy: 51.3125.. 0.1075 s/batch
# Epoch: 15/15.. Loss: 0.5851.. Test accuracy: 51.4375.. 0.1021 s/batch
# Epoch: 15/15.. Loss: 0.6068.. Test accuracy: 51.0000.. 0.0998 s/batch
# Epoch: 15/15.. Loss: 0.6475.. Test accuracy: 51.0000.. 0.1202 s/batch
# Epoch: 15/15.. Loss: 0.6277.. Test accuracy: 51.2500.. 0.1244 s/batch

# %% [markdown]
# Save best trained model.

# %%
## You should be familiar with how to save a pytorch model (Make sure to save the model in your Drive)
best_acc = 0.0

# ----- validation -----
net.eval()
correct = 0
total = 0

with torch.no_grad():
    for images, labels in valloader:
        outputs = net(images)
        _, preds = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (preds == labels).sum().item()

val_acc = correct / total
print(f"Validation accuracy: {val_acc:.4f}")

# ----- save best model -----
if val_acc > best_acc:
    best_acc = val_acc
    #save_path = "/content/drive/MyDrive/Colab Notebooks/best_model_hw1.pth"   # relative path
    save_path = "Weights_CNN.pth"
    torch.save(net.state_dict(), save_path)
    print(" Best model saved")
# Out:
# Validation accuracy: 0.8210
#  Best model saved

# %% [markdown]
# # Some visualisations and Interpretation questions
# This code allows us to look at the filters of the first layer of convolution :

# %%
def visualize_filters(layer, title='Filters'):
    filters = layer.weight.data.clone().cpu()
    filters = (filters - filters.min()) / (filters.max() - filters.min())
    grid = vutils.make_grid(filters, nrow=8, padding=2)
    plt.figure(figsize=(8,8))
    plt.imshow(grid.permute(1, 2, 0))
    plt.title(title)
    plt.axis('off')
    plt.show()

model = ConvNet() # Untrained model

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# --- Untrained filters ---
# "features[0]" is your first convolutionnal layer, you might have to change it to conv1 if it was the name you gave it to
# filters_untrained = model.features[0].weight.data.clone().cpu()
filters_untrained = model.conv1.weight.data.clone().cpu()
filters_untrained = (filters_untrained - filters_untrained.min()) / (filters_untrained.max() - filters_untrained.min())
grid_untrained = vutils.make_grid(filters_untrained, nrow=8, padding=2)
axes[0].imshow(grid_untrained.permute(1, 2, 0))
axes[0].set_title("Block 1 - First Conv Filters (Untrained)")
axes[0].axis("off")

# --- Trained filters ---
# Same thing here
filters_trained = net.conv1.weight.data.clone().cpu()
filters_trained = (filters_trained - filters_trained.min()) / (filters_trained.max() - filters_trained.min())
grid_trained = vutils.make_grid(filters_trained, nrow=8, padding=2)
axes[1].imshow(grid_trained.permute(1, 2, 0))
axes[1].set_title("Block 1 - First Conv Filters (Trained)")
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### What do you notice about the filters after the training ? Try to fin an interpretation about it.
#
# **Answer**: Before training, we have random colors with not structure. This is expected as the weight are initialized randomly. After training, some regions are more uniform, we observe some kind of color gradient, meaning the filters leanred something usefull about the image.

# %% [markdown]
# ### Activation maps
# This code snippet uses a forward hook to capture the output of the first convolutional layer of a CNN when a sample image is passed through it. The resulting activation maps show how each filter in the layer responds to different regions or features in the image.

# %%
def get_activation(model, layer, x):
    activation = {}
    def hook_fn(module, input, output):
        activation['output'] = output.detach().cpu()
    hook = layer.register_forward_hook(hook_fn)
    model(x)
    hook.remove()
    return activation['output']

data_iter = iter(trainloader)
sample_images, sample_labels = next(data_iter)
sample_img = sample_images[2].unsqueeze(0) #on fait varier l'indice ici !

# Get the feature maps after the first convolution (for example)
activation = get_activation(net, net.conv1, sample_img)

# Visualize a few feature maps in RGB:
def plot_feature_maps(feature_maps, n_cols=8):
    n_features = feature_maps.shape[1]
    n_rows = (n_features + n_cols - 1) // n_cols
    plt.figure(figsize=(n_cols * 1.5, n_rows * 1.5))
    for i in range(n_features):
        plt.subplot(n_rows, n_cols, i + 1)
        # Extract the i-th feature map from the first (and only) sample in the batch
        act = feature_maps[0, i, :, :]
        # Normalize the activation map to [0, 1]
        act_norm = (act - act.min()) / (act.max() - act.min() + 1e-8)
        # Repeat the single channel 3 times to form an RGB image
        act_rgb = act_norm.unsqueeze(0).repeat(3, 1, 1)
        plt.imshow(act_rgb.permute(1, 2, 0))
        plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_feature_maps(activation, n_cols=8)

# %% [markdown]
# ### 1. Feature Detection
# What specific features do you observe in these activation maps? Do some maps clearly highlight edges, contours, or textures? How might these features relate to the overall structure of the sample (e.g., the outline of a horse)?
#
# **Answer**: After the first conv layer, each of the 6 feature maps responds to a different low level pattern in the input image. Typically we see see some maps highlighting horizontal or vertical edges, others responding to color contrasts or textures. For an image like a horse, certain maps might light up strongly along the outline/silhouette while others respond to the background texture or internal regions. The key point is that early conv layers act as learned edge/texture detectors and each filter specializes in a different local pattern.
# ---
#
# ### 2. Effect of Training
# Consider how the activations might change after training versus an untrained (random) network. What does this tell you about the learning process?
#
# **Answer**: With an untrained network, the filters are random, so the activation maps look noisy and unstructured. They don't correspond to any meaningful visual feature. After training, the filters have been optimized via backprop to extract features that are actually usefull for classifying the 10 CIFAR classes. The activations become more structured and selective. This shows that training doesn't just adjust weights arbitrarily, it organizes the network to build a hierarchical feature detector, starting from low-level patterns in early layers.
